# %%
from pkasolver.query import query
from pkasolver.query import query_sdf
from pkasolver.query import query_sdf_to_img
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
IPythonConsole.molSize = 400,400

sdf_path = "/data/shared/projects/pkasolver-data-clean/00_AvLiLuMoVe_testdata.sdf"
# Out:
# Setting num threads to 1
# Pytorch will use cuda
# Attention pooling: False

# %%
mols, pkas, atoms = query("O=C([O-])C[NH+](CCN(CC(=O)[O-])CC(=O)[O-])CC(=O)[O-]")
print(mols, pkas, atoms)
# Out:
# [<rdkit.Chem.rdchem.Mol object at 0x7f7cde155280>, <rdkit.Chem.rdchem.Mol object at 0x7f7cde20dd00>, <rdkit.Chem.rdchem.Mol object at 0x7f7cde155f40>, <rdkit.Chem.rdchem.Mol object at 0x7f7cde438e80>, <rdkit.Chem.rdchem.Mol object at 0x7f7cde20de80>, <rdkit.Chem.rdchem.Mol object at 0x7f7cde20dd60>, <rdkit.Chem.rdchem.Mol object at 0x7f7cde20ddc0>] [5.887083053588867, 4.809606075286865, 4.694431304931641, 4.724119186401367, 6.504003047943115, 8.580707550048828] [15, 11, 2, 19, 7, 4]

# %%
draw_pairs = [] 
pair_atoms = []
pair_pkas = []
for i in range(len(mols)-1):
    draw_pairs.extend([mols[i], mols[i+1]])
    pair_atoms.extend([[atoms[i]], [atoms[i]]])
    pair_pkas.extend([pkas[i], pkas[i]])
Draw.MolsToGridImage(draw_pairs, molsPerRow=2, subImgSize=(250, 250), highlightAtomLists=pair_atoms, legends=[f"pka = {pair_pkas[i]:.2f}" for i in range(12)])

# %%
mol = mols[0]
IPythonConsole.molSize = 800,800
for atom, pka in zip(atoms, pkas):
    mol.GetAtomWithIdx(atom).SetProp('atomNote', f"{pka:.2f}" )

Draw.MolToImage(mol, size=(450,450))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=450x450 at 0x7F7E6C1A9E50>

# %%
query_sdf(sdf_path, "query.sdf")
# Out:
# opening .sdf file at /data/shared/projects/pkasolver-data-clean/00_AvLiLuMoVe_testdata.sdf and computing pkas...
# 361 pkas for 122 molecules predicted and saved at
# query.sdf

# %%
query_sdf_to_img(sdf_path)
# Out:
# opening .sdf file at /data/shared/projects/pkasolver-data-clean/00_AvLiLuMoVe_testdata.sdf and computing pkas...
# Name: 353
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=450x450 at 0x7F7CDD894C40>
# Name: 181
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=450x450 at 0x7F7CDD894DF0>
# Name: 177
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=450x450 at 0x7F7CDD8E97F0>
# Name: 587
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=450x450 at 0x7F7CDD8AC6A0>
# Name: 190
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=450x450 at 0x7F7CDD8ACC10>
# Name: 184
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=450x450 at 0x7F7CDD892AF0>
# Name: 365
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=450x450 at 0x7F7CDD8A1670>
# Name: 326
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=450x450 at 0x7F7CDD88EA00>
# Name: 427
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=450x450 at 0x7F7CDD8E9D60>
# Name: 471
# ...
